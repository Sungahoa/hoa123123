# %%
import pandas as pd

# Load the dataset
file_path = '/mnt/data/Shopping_CustomerData.csv'
df = pd.read_csv(r"C:\Users\PC\Downloads\Shopping_CustomerData.csv")

# %%
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
import seaborn as sns
# Vẽ sơ đồ đếm cho các cột đã chọn được sử dụng trong phân cụm
plt.figure(figsize=(30, 15))

# Vẽ sơ đồ đếm cho Tuổi khách hàng
plt.subplot(2, 2, 1)
sns.countplot(x=df['CustomerAge'])
plt.title('Customer Age')

# Vẽ sơ đồ thu nhập hàng năm
plt.subplot(2, 2, 2)
sns.countplot(x=pd.cut(df['AnnualIncome'], bins=10))
plt.xticks(rotation=90)
plt.title('Annual Income')

# Vẽ sơ đồ cho CreditScore
plt.subplot(2, 2, 3)
sns.countplot(x=pd.cut(df['CreditScore'], bins=10))
plt.xticks(rotation=90)
plt.title('Credit Score')

# Vẽ biểu đồ điểm chi tiêu
plt.subplot(2, 2, 4)
sns.countplot(x=df['SpendingScore'])
plt.title('Spending Score')

plt.tight_layout()
plt.show()
